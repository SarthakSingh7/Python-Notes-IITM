# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakSingh7/Python-Notes-IITM/blob/main/Python_Notes_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![7-2-python-logo-free-download-png-thumb.png](data:image/png;base64,...)

# %% [markdown]
# # Programming in python
#
# #Week 1: Introduction to Algorithms
#  W1L1 Introduction to Course

# %% [markdown]
# # W1L2 Introduction to Replit

# %%
print("Namaste")
# Out:
# Namaste1vhh3

# %%
print("*")
print("**")
print("***")
print("****")
print("*****")
print('*******')
# Out:
# *
# **
# ***
# ****
# *****
# *******

# %% [markdown]
# # W1L4 A Quick Introdution to Variables

# %%
print(10)
# Out:
# 10

# %%
a=10
print(a)
# Out:
# 10

# %%
a=10
b=20
print(b)
# Out:
# 20

# %%
a=10 
print(a)
b=20
print(b)
# Out:
# 10
# 20

# %%
a=10
b=20
print(a+b)
print(a*b)
# Out:
# 30
# 200

# %%
a=10
print(a)
a=a+1
print(a)
print(a)
print(a)
a=a+1
print(a)
a=a+1
print(a)
# Out:
# 10
# 11
# 11
# 11
# 12
# 13

# %% [markdown]
# #**These are called variables eg; a**

# %%
print("Enter a number")
n=int(input())
print(n)
print(n+1)
print(n+2)
print(n+3)
print(n+1000)
# Out:
# Enter a number
# 12
# 12
# 13
# 14
# 15
# 1012

# %% [markdown]
# ```
# n=int(input())
# ```
#
#
#
# this means:
#
# 1.please ask the person to input something
# **input()**
#
# 2.convert it into integer
# **int(input())**
#
# 3.And then assign it to **n**
#
# **n=int(input())**
#
#   we have to give a value when we run this in a code similar to the previous code where it asks for number and does operations on it.
#
# ```print("Enter a number")
# n=int(input())
# print(n)
# print(n+1)
# print(n+2)
# print(n+3)
# print(n+1000)
# ```

# %% [markdown]
# #W1L5 Variables and Input statement

# %%
print("Hello, type your name")
n=str(input())
print(n)
# Out:
# Hello, type your name
# Sarthak
# Sarthak

# %% [markdown]
# This is also similar to the previous code but here we dont need integer, we need string value so,
# ```
# n=str(input())
# ```
#
# 1.please ask the person to input something
#
# **input()**
#
# 2.convert it into string
#
# **str(input())**
#
# 3.And then assign it to n
#
# **n=str(input())**
#
#
# the code below asks a name to the person
#
#
# ```
# print("Hello, type your name")
# n=str(input())
# print(n)
# ```
# but it can be used in many other operations

# %%
print("Hello, type your name")
n=str(input())
print("Hello",n,"How are you?.")

#this program is used to say hello to the person giving an input
# Out:
# Hello, type your name
# Sarthak
# Hello Sarthak How are you?.

# %%
print("Hello, type your name")
n=str(input())
print("Which place are you in?")
p=str(input())
# Out:
# Hello, type your name
# Sarthak
# Which place are you in?
# Dehradun

# %% [markdown]
# ```
# print("Hello, type your name")
# n=str(input())
# print("Which place are you in?")
# p=str(input())
# ```
#
#
#
# note that here we used p instead of n becasue if we use the same variable then it will forget the
# previous input of n, so we used p instead of n to store the place
# variables are like a bucket that stores data.

# %%
#we can add more complexity to it 

print("Hello, type your name")
n=str(input())
print("Which place are you in?")
p=str(input())
print("Hello",n,"How is the weather in", p,"?" )
w=str(input())
print("What is your age?")
age=int(input())
print("Good to know you are",age,"years old")
# Out:
# Hello, type your name
# Sarthak
# Which place are you in?
# Dehradun
# Hello Sarthak  How is the weather in Dehradun ?
# light showers
# What is your age?
# 21
# Good to know you are 21 years old

# %% [markdown]
# # Note
# In the above code there is a gap in the sentence "Hello Sarthak  How is the weather in **Dehradun ?**", To solve this problem we use %p instead of p.
#
# This is called *format specifier*.

# %%
#we can add more complexity to it 

print("Hello, type your name")
n=str(input())
print("Which place are you in?")
p=str(input())
print("Hello",n,"How is the weather in %p?")
w=str(input())
print("What is your age?")
age=int(input())
print("Good to know you are",age,"years old")

# %% [markdown]
# #How to Write notes and remarks (Not in video lec)

# %%
print("Hello, type your name")
n=str(input())
print("Hello",n,"How are you?.")

#Method 1: by using a hashtag we can write notes.
#in this we have to put hashtag after every line

'''
method 2: we can also write big notes in this format just put the correct symobols 
as done above and below of this note 
the code will not be effected from it but it will apper in the output box.
'''

"""""
sample note 1

"""""

# Method 3
# if i we want to type big 
# notes 
# like this 
# which are not 
# in a 
# single 
# line
# then we can use a shotcut
# select all the text and
# then at the top press ctrl + [?/] button
# it will autimatically put hashtag
# on everyline 
# yes 
# everyline.
# Out:
# Hello, type your name
# Sarthak
# Hello Sarthak  How are you?.
# '""\nsample note 1\n\n'

# %% [markdown]
# #W1L6 Variables and literals

# %%
print("Type your name:")
n=str(input())
print("Type your location:")
p=str(input())
print("Hello", n, "How is the weather in", p,"?")
w= str(input())
print("What is your age?")
age= int(input())
print("Good to know that you are", age, "years old")
# Out:
# Type your name:
# Sarthak
# Type your location:
# Dehradun
# Hello Sarthak How is the weather in Dehradun ?
# rainy
# What is your age?
# 21
# Good to know that you are 21 years old

# %% [markdown]
# #Is it necessary to have print and input as 2 seprate commands or we can merge them together?
#
# Ans: print commands only prints the message, The input command (say) n=str(input()) takes an input and stores that value to a variable 'n'
#
# This printing a message and taking a input can be combined together, The same message we can place inside the brackets of input command and we can remove this print.
# See example in the code below

# %%
n=str(input("Type your name: "))
p=str(input("Type your location:") )
print("Hello", n, "How is the weather in", p,"?")
w=str(input())
age=int(input("What is your age?"))
print("Good to know that you are", age, "years old")

#Here we use the variables to get the input without the print command
# Out:
# Type your name: Sarthak
# Type your location:Dehradun
# Hello Sarthak  How is the weather in Dehradun ?
# Good
# What is your age?21
# Good to know that you are 21 years old

# %% [markdown]
# #What are variables?
# In the above examples **n, p, age** were variables which means their values can be changed, they are nothing but a container where we can store different values.

# %% [markdown]
# Example
# Let us say **name** adn **age** are variables variables.
#
#
# ```
# name= "Sarthak"
#
# age= 21
# ```
# name and age are variables and the value that it has stored is called **literals**
# Sarthak and 21 are literals for the respective variables.

# %% [markdown]
# name = "Sarthak"
#
# name is a variable
# "Sarthak" is the literal (The value that the variable stores)
#
# a variable can store different literal values.
# literals can be modified as per requirements.

# %% [markdown]
# #More on Variables and Literals
#
# ```
# age = 21
# age = age + 1
#
# #as per this particular line number 2, what we are saying, take the latest value
# of age which is 21, add 1 into it and store the updated values in variable age.
#
# ```
# Here we can see that the age is a variable and can be used on either side of = i.e. LHS or RHS
# But, the literals cant be used on the LHS
# They can be used only on the RHS
#
# Hence, you can conclude the literals can be used only on the right hand side of the equal.

# %% [markdown]
# #When to use a variable and when to use a literal?

# %%
r = int(input('Enter the radius of the circle:'))
area = 3.14* r* r
print('Area of the circle with radius', r, 'is', area)
# Out:
# Enter the radius of the circle:5
# Area of the circle with radius 5 is 78.5

# %% [markdown]
# The answer lies in the line 2 of the code above, we use **r** as a variable **area** as a variable but the value of *pi* (3.14) as literal,
# because value of pi will never change, whereas radius of a circle might change, and with
# respect to that area will also change, which means we can execute this program again.
#
# And instead of 5 now we can enter 15, which will give us a new area value which is 706.5,
# irrespective of the radius of the area the value of pi is always 3.14.
#
# *We will use variables only when there is a possibility that the value which is being
# stored make change and when we are sure that the value is not going to change we will literal*.

# %% [markdown]
# #W1L7 Data Types 1

# %% [markdown]
# Python has different data types
#
# some of them are:
# 1. int
# 2. str
# 3. float
# 4. list

# %%
n = 10
print(n) #Here n is of integer type and to know the class of a variable we use 'type()' function.
print(type(n)) 

r=6.3         #here r is not a integer it is of float type.
print(r)
print(type(r))

s='Sarthak'  #Here s is of string type
print(s) 
print(type(s))

p= 22.4
print("p is od type:",type(p))
print(type(p))

#both the commands are same
# Out:
# 10
# <class 'int'>
# 6.3
# <class 'float'>
# Sarthak
# <class 'str'>
# p is od type: <class 'float'>
# <class 'float'>

# %% [markdown]
# **float** is floating point reprersentation of a number, this is the way in which computer stores a number which is not a integer.
# float means the number is beyond an integer.

# %%
#python has different data  types

l=[10,20,30,'sarthak',24.36]

print(l)

print(l[0])

print(l[1])

print(l[2])

print(l[3])

print(l[4])

print(type(l))

#here L represents a list
# Out:
# [10, 20, 30, 'sarthak', 24.36]
# 10
# 20
# 30
# sarthak
# 24.36
# <class 'list'>

# %% [markdown]
# **List**
#
#
#
# `l=[10,20,30,'sarthak',24.36]`
#
#
#
# 1.  here l is a list.
# 2.  it can store str, int, float all these types of values.
# 3.  **Note that the computer stores values starting from 0.**

# %% [markdown]
# ![data type py.png](data:image/png;base64,...)

# %% [markdown]
# #W1L8 Data Types 2

# %% [markdown]
# **Boolean data type**
#
# Data type with one of the two built-in values, True or False. Boolean objects that are equal to True are truthy (true), and those equal to False are falsy (false). But non-Boolean objects can be evaluated in Boolean context as well and determined to be true or false. It is denoted by the class bool.
#
# *Note – **True** and **False** written starting with capital ‘T’ and ‘F’ **are valid** booleans otherwise python will throw an error*.

# %%
i= 10      # data type: int
f= 5.6     # data type: float
s= 'India' # data type: Str 


b1= True   # both b1 and b2 are of data type bool (boolean)
b2= False




print(type(i))
print(type(f))
print (type(s))

print (type(b1))
print (type(b2))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# **Note**
# ```
# b3= true
# b4= false
#
# b5= T
# b6= F
# ```
# These are not defined as bool (boolean)

# %% [markdown]
# #**python data type conversion**

# %%
# To convert float data type to integer and string
#Question1: convert a,b and c to integer, string, float, float data type respectively.

a=5.7  
print(type(a))
b=10.45
print(type(b))
c= 3
print(type(c))
d='3.14'
print(type(d))

#solution

e= int(5.7)
f= str(10)
g= float(3)
h= float('3.14')

print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'float'>

# %%
#example: conversion from int and str to float

a= float(9)
b= float('5.3')                     #Note that '5.3' represents string.

print(a, type(a))
print(b, type(b))
# Out:
# 9.0 <class 'float'>
# 5.3 <class 'float'>

# %%
#example: conversion from int and str to float

a= float(9)
b= float('5.3')                     #Note that '5.3' represents string.

print(a, type(a))
print(b, type(b))
# Out:
# 9.0 <class 'float'>
# 5.3 <class 'float'>

# %%
#example: conversion from float to str

a= str(9)
b= str(5.1)

print(a, type(a))
print(b, type(b))
# Out:
# 9 <class 'str'>
# 5.1 <class 'str'>

# %%
#conversion from integer data type to boolean data type

a= bool(10)
b= bool(0)
c= bool(-10)
d= bool(7)


print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
# Out:
# True <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>
# True <class 'bool'>

# %% [markdown]
# Class or type of variables a, b, and c is Boolean but if you observe the values then you will notice there is some difference
#
# Value for variable b is coming out to be False, whereas values for variable a and c are True.
#
# This is happening because whenever computer converts an integer to a Boolean, all values
#
# except 0 are consider as True whereas 0 is the only value which will give us Boolean representation which is False
#
#
# That is the reason 10 ,7 as well as -10 are getting converted to Boolean value True,
# whereas 0 is converted to Boolean value False.

# %%
#conversion from float data  type to boolean data type 

a= bool(10.5)
b= bool(0.0)
c= bool(-11.6)

print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# True <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>

# %%
#str to boolean

a= bool('India')
b= bool('10')
c= bool('-10.4')
d= bool('0')
e= bool('')

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
print(e, type(e))
# Out:
# True <class 'bool'>
# True <class 'bool'>
# True <class 'bool'>
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# NOTE:
#
# ```
# a= bool('India')
# b= bool('10')
# c= bool('-10.4')
# d= bool('0')
# e= bool('')
#
# ```
# in the code above for conversion from str to boolean
# the only value which will be false is the the value of variable e
# an empty str:   ''
# only this will give a false value rest all str will give a true value
#
# anything which has'' on start and end is considered to be a str
#
# 'India', '100.65' these are some of the examples of str.

# %% [markdown]
# #W1L9 Operators and Expressions 1

# %%
#This code does what we expect it to do
a= 1.1
b=2.28
x=a+b
y=a*b

print(x,y)
# Out:
# 3.38 2.508

# %%
# now the same thing with strings; firstly we use the addition operation(+)

a= 'Sarthak'
b= 'India'

x=a+b

print(x)

#The computer understands the addition of 2 strings
# Out:
# SarthakIndia

# %% [markdown]
# #Note for the code above
#
# This is called **Concatenation** in english
# and more so in *computer science* this
# is very often used, they call it **concatenate**, put  two words together, one next to the other.
#
# So, whenever you say plus of two strings, the  computer seems to understand that

# %%
# if we want to multiply the str then;

a= 'Sarthak'
b= 'India'

y= a*b

print(y)

#the computer dosen't understand the product of 2 str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d80ca4a6217e> in <module>()
#       4 b= 'India'
#       5
# ----> 6 y= a*b
#       7
#       8 print(y)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
#  **the question arises that the computer understands + and does Concatenation joins the 2 words but nothing happens in -, *, / ( subtraction, multiplication, division)**
#
# This is because the computer is programmed that way to understand addition as concatenation. It is for convenience that they use + sign for concatenation of 2 strings

# %%
 #Concatenation of lists
 
 a= [1,2,3]
 b= [2,7,9,15]

 x= a+b  

# note that x does not give the union of the 2 lists
# as a repetition can occur in the list, therefore not a union

print(x)
# Out:
# [1, 2, 3, 2, 7, 9, 15]

# %% [markdown]
# #Note
#
# from all the previous examples we understand that the data type matters when we do opearations like addition+, subtraction-, multiplication etc.

# %%
a= 11
b= 15

n= a/b

print(n, type(n))

# the output is in float data type
# Out:
# 0.7333333333333333 <class 'float'>

# %%
n=10+13*2

#My guess is that n will be 36 (using BODMAS rule)

print(n)

# The expected answer was correct and it was 36.
# That is due to the "Operator Precedence"
# Out:
# 36

# %% [markdown]
# #Note
# When more than one operator appears in an expression, the order of evaluation depends on the rules of precedence. For mathematical operators, Python follows mathematical convention. The acronym **PEMDAS** is a useful way to remember the rules.
#
# Some operators are precedence over the other. They are executed first over the other.

# %% [markdown]
# #PEMDAS
#
# PEMDAS is an acronym used to mention the order of operations to be followed while solving expressions having multiple operations. PEMDAS stands for **P- Parentheses, E- Exponents, M- Multiplication, D- Division, A- Addition, and S- Subtraction**.

# %% [markdown]
# #W1L10 Operators and Expressions 2

# %% [markdown]
# In Python operators are divided
# into three major categories:
#
# * **arithmetic  operators**
# * **relational operators**
# * **logical operators**

# %% [markdown]
# #What are operators?
# ***Operators*** are special symbols that represent computations like
# addition and multiplication. The values the operators are applied to are called ***operands***.
#
# The Operators(+, -*, **, **,and /) perform addition,subtraction,multiplication,exponentiation and division
#
# exponentiation it is nothing new, it is just a fancy term of power.
# eg: 2**5+34 = 66

# %% [markdown]
# #1.Arithmetic operators

# %% [markdown]
# ```
# (+, -,  *, **, /, //, %)
# these are some of the arithmetic operators
# ```

# %%
print('Addition', 2 + 3)
print('Subtraction', 9 - 1)
print('Multiplication', 5 * 4) 
print('Division', 7 / 3)
# Out:
# Addition 5
# Subtraction 8
# Multiplication 20
# Division 2.3333333333333335

# %% [markdown]
# #Division (float)
#
# ```
# # print(10/2)
# ```
# this gives a output 5.0
# the type of the output is float.

# %%
print(10/2)
# Out:
# 5.0

# %% [markdown]
# #Important Note: (Division)
#
# #division (/) changes the data type to float

# %% [markdown]
# #Floor division (//)
# difference between division operator / and floor division operator // is:
#
# Whenever we divide 7 by 3,we get some fractional value, but when we  divide 7 by 3 using a floor division operator (//)
#
# it provides us only the integer part of  that division, which is 2 in this case.
#
# ## the floor division function (//) always give the output in integer format.
#
# #Floor division can be treated as the G.I.F. function or floor function
# #gratest integer fuction.
#
#
# #note there are 2 types of function floor and ceiling functions
#
# ##Greatest integer function returns the greatest integer less than or equal to a real number. ... This function is also known by the names of “floor” or “step” function. The greatest integer function (GIF) is denoted by the symbol “[x]” .
#
# ![gratest integher function.png](data:image/png;base64,...)

# %%
#Floor Division (//)

print('Floor division', 7 // 3 )
# Out:
# Floor division 2

# %% [markdown]
# #**Important note**
#
# ## If we keep numerator or denominator or both in float data type then the output will also in float data type after floor division.

# %% [markdown]
# #Modulus operator %
#
# We are getting this output as 1 because  whenever we divide 7 by 3, the remainder is  1, division operator gives us the  output in fractional value.
# Floor division divides the numbers and  provides only the integer quotient part of it.
# **Whereas modulus operator provides the remainder after the division.**
#
# It is denoted by the symbol **%**.

# %%
#Modulus operator %

print('Modulus', 7 % 3)
# Out:
# Modulus 1

# %% [markdown]
# #Exponentiation Operator **
#
# it is simply used to denote the powers/Index of the number
#
# eg; 3^2 = 3*3
#
# this can be written as 3**2
#
# eg: square root of 2 can be written as
#
# 2**(1/2)

# %%
#Exponentiation **

print('Exponentiation', 6**2)

#eg: square root of 2

print('Square root of two:', 2**(1/2))
# Out:
# Exponentiation 36
# Square root of two: 1.4142135623730951

# %% [markdown]
# #2. Relational Operators

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Relational operators(>, <, >=, <=, ==, !=)

print(5 > 10)
print(10 > 5)

print(5 < 10)
print(10 < 5)

print(5 > 5)
print(5 >= 5)
print(5 <= 5)

print(5 == 60)
print(5 == 5)

print(5 != 60)
print(5 != 5)
# Out:
# False
# True
# True
# False
# False
# True
# True
# False
# True
# True
# False

# %% [markdown]
# #Note
# the output values of the relational operators are always **boolean** values
#
# either it is **True** or it is **False**.

# %% [markdown]
# #3.Logical Operators
# There are three logical operators: **and, or,** and **not**. The semantics (meaning) of these operators is similar to their meaning in English.
#
# For example, x > 0 and x < 10 is true only if x is greater than 0 and less than 10.
#
# n%2 == 0 or n%3 == 0 is true if either of the conditions is true, that is, if the number is divisible by 2 or 3.
#
# Finally, the not operator negates (make ineffective/nullify) a boolean expression,
#
# so, not (x > y) is true if x > y is false; that is, if x is less than or equal to y.
#
# **Strictly speaking, the operands of the logical operators should be boolean expressions, but Python is not very strict. Any nonzero number is interpreted as “true.”**

# %% [markdown]
# #and

# %%
#Logical Operators 
#(and, or, not)

#eg; and Operator

print(True and True)        #gives True only in this case
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #or operator

# %%
#eg; or operator

print(True or True)        
print(True or False)
print(False or True)
print(False or False) #gives False only in this case, rest all are true
# Out:
# True
# True
# True
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #not operator

# %%
#eg; not operator

print(not (True))

print(not False)
# Out:
# False
# True

# %% [markdown]
# output is false followed by true, not of  true is false, whereas not of false is true,
# which means this not operator simply inverts  the Boolean value from true to false and from false to true.
#
# But you must have observed one  difference in these two print statements.
# In first print statement I have used not  followed by a bracket inside which I have used a Boolean value true whereas in second print  statement I have used not operators followed by
# false directly without using any parentheses,  still we are getting the expected output which means **the not operator can be used either with brackets or without brackets**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #W1L11 Introduction to strings

# %%
s= 'coffee'
t= 'Cookies'

print(s)
print(t)
print(s+t)      #Concatenation
print(s+"-"+t)
print(s+'&'+t)
print(s+' & '+t)
# Out:
# coffee
# Cookies
# coffeeCookies
# coffee-Cookies
# coffee&Cookies
# coffee & Cookies

# %% [markdown]
# #String indexing and String Slicing

# %%
s='coffee'

print(s[0]) # this is called string indexing 
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])

# coffee has only 6 letters

print(s[0:0])
print(s[0:1])
print(s[0:2])
print(s[0:3])   #(it is starting from the first number 1  s of 1, it is starting and going up to  
print(s[0:4])            #2, it does not go up to 3, it goes  one less)
print(s[0:5])
print(s[0:6])
# Out:
# c
# o
# f
# f
# e
# e
#
# c
# co
# cof
# coff
# coffe
# coffee

# %% [markdown]
# #**Python starts with 0.**
# so, does your C language.  Anything before c with the best of my knowledge
# would always start with 1, the list would  start with 1, the string would start with 1,
# you would refer it as s of 1 for c, but in Python  you start with s of 0 for the first letter.
#
# So, if we are typing
#
# ```
# s='coffee'
# print(s[0:4])
# ```
#
#  it means that python will show the output as coff (till the 4 elements but we have put range of 5 elements 0-4 is 5 numbers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s= 'coffee'

print(s[3:5]) #one less than the original number in the range
              #  because python starts with 0
print(s[3:6])

#this is called string slicing
# Out:
# fe
# fee

# %% [markdown]
# ##This is called string slicing.

# %% [markdown]
# #More on str slicing
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = '0123456789'

a=s[0]
b=s[1]

print(a)
print(b)
# Out:
# 0
# 1
# 01

# %%
s = '0123456789'

a=s[4]
b=s[7]

print(a)
print(b)

print(a+b, type(a+b)) #expected output is 4 + 7 = 11

# But the output did not matched the expected output becasuse here 4 is not a int and 
# 7 is also not a int thyey both are str '4' and '7' so it is simply the concordinatiopn of the two str
# ie 47 and here 47 is a str
# Out:
# 4
# 7
# 47 <class 'str'>

# %%
#if we want the answer to be 11 and an integer then;

s = '0123456789'

a=int(s[4])
b=int(s[7])

print(a)
print(b)

print(a+b, type(a+b))

#by converting them to int we get our desired output and it is of int data type
# Out:
# 4
# 7
# 11 <class 'int'>

# %% [markdown]
# The way your  computer sees things depends on how you store them
# and computer stores in its own way  unless or otherwise specified.
#
#
# You may have to specify in what  format you want this to be stored
# just so that you can do the necessary operations  on it.

# %%
s = '0123456789'

a=s[3]
b=s[8]

n= int(a+b)

print(n)
# Out:
# 38

# %%
s = '0123456789'

a=int(s[3])
b=int(s[8])

n= int(a+b)

print(n)
# Out:
# 11

# %% [markdown]
# #W1L12 More on Strings

# %% [markdown]
# In last lecture we saw various concepts related to strings, like  **concatenation, indexing,
# and slicing.**
# In this lecture we will see few more concepts related to strings.
# In the first concept, it is called **replication.**

# %%
# Replication 

s= 'good'

print(s*5) 

# multiplication is just repeated addition.
# procedure like concatenation takes place in this case
# Out:
# goodgoodgoodgoodgood

# %% [markdown]
# It prints the string 5 times one after the another, which means it is like an concatenation
# operator where same string is concatenated with itself 5 times.

# %%
s ='good'

print(s[0]*82)

#this is also an example of replication in python
# Out:
# gggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggggg

# %% [markdown]
# #Comparision

# %%
x = 'India'

print(x == 'India')
print(x == 'india')

#a single letter change from capital 'I' to small 'i' mamkes it false.
# Out:
# True
# False

# %%
print('apple' > 'one')

print('four' < 'ten')

#str comparison
# Out:
# False
# True

# %% [markdown]
# # Reason for such output of comparision
#
# * A computer starts the comparison process character by character as in the zeroth letter of first string which is a in this case will be compared against the zeroth letter of second string,
# which is o in this case.
#
# * That means a computer will compare whether a is greater than o.
#
# * As we know in alphabetical order a comes before o, which means a is not greater than o, because
# of that it results into false.
#
# * Similarly, in second case the letter f is less than t because the letter f comes before letter t in an alphabetical order, because of that it says true.

# %%
# what happens when the first letter is equal 

print('ab' < 'az')

print('ab' < 'aa')

print('abcdef' < 'abcde')  #here letters a to e are same then the other comparision 
                           # of f cant be done with nothing that is f cannot be less than nothing/no value
                           # so it shows output false
# Out:
# True
# False
# False

# %% [markdown]
# #Positive str indexing

# %%
s = 'python'

print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
# Out:
# p
# y
# t
# h
# o
# n

# %% [markdown]
# #Negative str indexing

# %%
s = 'python'

print(s[-1])  
print(s[-2])
print(s[-3])
print(s[-4])
print(s[-5])
print(s[-6]) #This shows the first letter of the str

# it is also giving a output
# Out:
# n
# o
# h
# t
# y
# p

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #length of str
#
# print(len(s))

# %%
s = 'gfjsdgvcsvvsdsadvmhsctgvmgbcygfrkuyfhrafgakvbjhbfgvhjhvcbcnsbSDFKUAHKLVCHHBb'

# these are randomly typed keys 

# how to find the length of the total (total number of letters)


print(len(s))

# usiong len (which gives length) we have the total number of lettes i.e 76
# Out:
# 76

# %%
s = 'gfjsdgvcsvvsdsadvmhsctgvmgbcygfrkuyfhrafgakvbjhbfgvhjhvcbcnsbSDFKUAHKLVCHHBb'

print(s[76])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-a007923ae34d> in <module>()
#       1 s = 'gfjsdgvcsvvsdsadvmhsctgvmgbcygfrkuyfhrafgakvbjhbfgvhjhvcbcnsbSDFKUAHKLVCHHBb'
#       2
# ----> 3 print(s[76])
#
# IndexError: string index out of range

# %% [markdown]
# #Note
# the above code shows error because the (+) index in python starts from 0 so, for 76 letters it will have to be 0 to 75
# therefore, the command
#
# ```
# print(s[76])
# ```
# is showing error.
#
# ## we can use the number which is 1 less than the total length of the str.
# ##and that number is the highest possible index
# ##here the highest possible index is 75.

# %% [markdown]
# #W1L13 conclusions and FAQs

# %% [markdown]
# ****
# #Extra informations (not in course)

# %% [markdown]
# ###Some other operators
#
# **Logical AND (&&) Logical OR (||)**
#
#  Logical AND (&&) and logical OR (||) are called logical operators. They compare operands and return a result of either true (1) or false (0). In logical AND, if both operands are true then the result is true. If either one of the operands is false, the result will be false. In logical OR, if both operands are true or either one of the operands is true then the result is true. If both operands are false then the result will be false.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Check for git
